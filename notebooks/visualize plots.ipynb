# %%
import sys
sys.path.append('../src/data')
import get_data as gd
import make_dataset as md
sys.path.append('../src/visualization')
import plot as pl
import visualize as vz

# %%
dataset_df = gd.get_train_data().drop('Id', axis=1)
fig = pl.house_price(dataset_df)

# %%
df_num = dataset_df.select_dtypes(include = ['float64', 'int64'])
df_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8);

# %%
import tensorflow_decision_forests as tfdf
# Out:
# 2024-05-03 10:24:46.927075: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-03 10:24:46.932256: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-03 10:24:46.990969: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-03 10:24:48.266753: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
graph = vz.evaluate_logs(dataset_df, tfdf.keras.RandomForestModel)
# Out:
# Warning: The `num_threads` constructor argument is not set and the number of CPU is os.cpu_count()=72 > 32. Setting num_threads to 32. Set num_threads manually to use more than 32 cpus.
# WARNING:absl:The `num_threads` constructor argument is not set and the number of CPU is os.cpu_count()=72 > 32. Setting num_threads to 32. Set num_threads manually to use more than 32 cpus.
# Use /tmp/tmp6sztp4so as temporary training directory
# Reading training dataset...
# WARNING:tensorflow:6 out of the last 6 calls to <function CoreModel._consumes_training_examples_until_eof at 0x7f760f23c720> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function CoreModel._consumes_training_examples_until_eof at 0x7f760f23c720> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Training dataset read in 0:00:00.907278. Found 1029 examples.
# Training model...
# [INFO 24-05-03 10:26:46.9744 UTC kernel.cc:1233] Loading model from path /tmp/tmp6sztp4so/model/ with prefix 67466e6f053c48ed
# Model trained in 0:00:00.913444
# Compiling model...
# [INFO 24-05-03 10:26:47.3340 UTC decision_forest.cc:734] Model loaded with 300 root(s), 97724 node(s), and 73 input feature(s).
# [INFO 24-05-03 10:26:47.3341 UTC kernel.cc:1061] Use fast generic engine
# WARNING:tensorflow:5 out of the last 5 calls to <function InferenceCoreModel.make_predict_function.<locals>.predict_function_trained at 0x7f75f438b560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function InferenceCoreModel.make_predict_function.<locals>.predict_function_trained at 0x7f75f438b560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model compiled.
# WARNING:tensorflow:5 out of the last 9 calls to <function InferenceCoreModel.yggdrasil_model_path_tensor at 0x7f75f4585800> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 9 calls to <function InferenceCoreModel.yggdrasil_model_path_tensor at 0x7f75f4585800> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
vz.plot_inspector(dataset_df)
# Out:
# Warning: The `num_threads` constructor argument is not set and the number of CPU is os.cpu_count()=72 > 32. Setting num_threads to 32. Set num_threads manually to use more than 32 cpus.
# WARNING:absl:The `num_threads` constructor argument is not set and the number of CPU is os.cpu_count()=72 > 32. Setting num_threads to 32. Set num_threads manually to use more than 32 cpus.
# Use /tmp/tmpvo9ax4r6 as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:00.732220. Found 1004 examples.
# Training model...
# [INFO 24-05-02 15:59:14.6430 UTC kernel.cc:1233] Loading model from path /tmp/tmpvo9ax4r6/model/ with prefix 2465927790004c91
# Model trained in 0:00:00.665546
# Compiling model...
# [INFO 24-05-02 15:59:14.9103 UTC decision_forest.cc:734] Model loaded with 300 root(s), 95422 node(s), and 75 input feature(s).
# [INFO 24-05-02 15:59:14.9104 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
