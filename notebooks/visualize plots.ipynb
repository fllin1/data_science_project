# %%
import sys
sys.path.append('../src/data')
import get_data as gd
import make_dataset as md
sys.path.append('../src/visualization')
import plot as pl
import visualize as vz
# Out:
# 2024-05-02 15:58:42.727212: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-02 15:58:42.733195: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-02 15:58:42.790024: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-02 15:58:43.507385: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
dataset_df = gd.get_train_data().drop('Id', axis=1)
fig = pl.house_price(dataset_df)

# %%
df_num = dataset_df.select_dtypes(include = ['float64', 'int64'])
df_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8);

# %%
vz.evaluate_logs(dataset_df)
# Out:
# Warning: The `num_threads` constructor argument is not set and the number of CPU is os.cpu_count()=72 > 32. Setting num_threads to 32. Set num_threads manually to use more than 32 cpus.
# WARNING:absl:The `num_threads` constructor argument is not set and the number of CPU is os.cpu_count()=72 > 32. Setting num_threads to 32. Set num_threads manually to use more than 32 cpus.
# Use /tmp/tmpx8lsqyfd as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:02.968917. Found 1003 examples.
# Training model...
# [INFO 24-05-02 15:59:06.8840 UTC kernel.cc:1233] Loading model from path /tmp/tmpx8lsqyfd/model/ with prefix 0dc38edc385947f4
# Model trained in 0:00:00.677776
# Compiling model...
# [INFO 24-05-02 15:59:07.1437 UTC decision_forest.cc:734] Model loaded with 300 root(s), 95424 node(s), and 74 input feature(s).
# [INFO 24-05-02 15:59:07.1437 UTC abstract_model.cc:1344] Engine "RandomForestOptPred" built
# [INFO 24-05-02 15:59:07.1437 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.

# %%
vz.plot_inspector(dataset_df)
# Out:
# Warning: The `num_threads` constructor argument is not set and the number of CPU is os.cpu_count()=72 > 32. Setting num_threads to 32. Set num_threads manually to use more than 32 cpus.
# WARNING:absl:The `num_threads` constructor argument is not set and the number of CPU is os.cpu_count()=72 > 32. Setting num_threads to 32. Set num_threads manually to use more than 32 cpus.
# Use /tmp/tmpvo9ax4r6 as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:00.732220. Found 1004 examples.
# Training model...
# [INFO 24-05-02 15:59:14.6430 UTC kernel.cc:1233] Loading model from path /tmp/tmpvo9ax4r6/model/ with prefix 2465927790004c91
# Model trained in 0:00:00.665546
# Compiling model...
# [INFO 24-05-02 15:59:14.9103 UTC decision_forest.cc:734] Model loaded with 300 root(s), 95422 node(s), and 75 input feature(s).
# [INFO 24-05-02 15:59:14.9104 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.
